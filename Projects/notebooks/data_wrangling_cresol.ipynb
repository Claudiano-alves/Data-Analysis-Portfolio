# %%
# %load_ext autoreload
# %autoreload 2

# import sys 
# sys.path.append("..") 
import sys
sys.path.append(r"C:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import importlib 
#from utils import queries
#from utils.mailing import pipelines, metricas_acumuladas, data_processing
#from Renner.src.mailing import metricas_acumuladas, data_processing, pipelines
#from utils.acionamentos import metricas_acumuladas
#from utils.discagens.expert import pipelines, data_processing, metricas_acumuladas
#from utils.acionamentos import pipelines, metricas_acumuladas, data_processing
#from utils.discagens.expert.Ringing import metricas_acumuladas
#from utils.pagamentos import pipelines, metricas_acumuladas, data_processing
#from utils import utils, config, queries
#from utils.digital_channels import data_processing, metricas_acumuladas
#from utils.discagens.expert.Ringing import metricas_acumuladas
from utils._database import insert
from Cresol.src import database, config
#from Cresol.src.discagens import discagens_pipeline
#from Renner.src.mailing import data_processing, as
#from Renner.utils import queries

# importlib.reload(data_loader)
# importlib.reload(queries)
# importlib.reload(data_wrangling_mailingHist)
# #importlib.reload(queries)
#importlib.reload(utils)
importlib.reload(database)
importlib.reload(config)
importlib.reload(insert)
#importlib.reload(metricas_acumuladas)
#importlib.reload(pipelines)
#importlib.reload(data_processing)
#importlib.reload(data_loader)
#importlib.reload(queries)
# Out:
# <module 'utils._database.insert' from 'C:\\Users\\claudiano.alves\\Documents\\Claudiano\\repository\\Data-Analysis-Portfolio\\Projects\\utils\\_database\\insert.py'>

# %%
# sobe para Projects 
from Cresol.src.data_loader import load_data_cresol

dados = load_data_cresol('2026-01-01', '2026-01-31')

(
df_discagens_expert,
df_mailing_hist, 
df_tab_acionamentos, 
df_tabulacao_aciona,
df_dw_calendario, 
df_pagamentos, 
df_acordos, 
df_sms,
df_rcs,
df_email,
df_whats
) = dados.values()
# Out:
# 🔌 Conectando aos bancos de dados...
# ✅ Conexões estabelecidas
#
# 📊 Carregando dados de 2026-01-01 até 2026-01-31...
# C:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\utils\data_loader.py:227: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conexao)
# [1/11] ✓ Discagens Expert: 965.316 registros (4m 38s)
# [2/11] ✓ Mailing Histórico: 969.604 registros (5m 50s)
# [3/11] ✓ Tabulação de Acionamentos: 37.395 registros (26s)
# [4/11] ✓ Tabulação Acionamentos: 9.794 registros (0s)
# [5/11] ✓ Calendário: 21 registros (0s)
# [6/11] ✓ Pagamentos: 0 registros (2s)
# C:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\utils\data_loader.py:227: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conexao)
# [7/11] ✓ Acordos: 1.892 registros (1s)
# [8/11] ✓ SMS: 19.482 registros (0s)
# [9/11] ✓ RCS: 20.211 registros (0s)
# [10/11] ✓ Email: 0 registros (2s)
# C:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\utils\data_loader.py:227: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conexao)
# [11/11] ✓ WhatsApp: 0 registros (0s)
#
# ✅ Carregamento concluído em 11m 3s
# 🔌 Conexão TRC fechada
# 🔌 Conexão BD2 fechada
# 🔌 Conexão SRC fechada

# %%
df_discagens_expert
df_mailing_hist
df_mailing_acumulado
#df_discagens_expert.shape
# Converte a visão de valores em uma lista e acessa o primeiro
# df = list(df_discagens_expert)[0]

# print(df.shape)
# df.info()

# Se você usou algo como: dfs_dit = pd.read_excel('arquivo.xlsx', sheet_name=None)
# Para iterar e identificar cada um:
# Out:
#           DATA        Indicador    qte   PF_PJ                         PA  \
# 0   2026-01-02        Contratos     97      PF              ASCOOB CRESOL
# 1   2026-01-02        Contratos    972      PF       CENTRAL BRASIL EXTRA
# 2   2026-01-02        Contratos  16630      PF               CRESOL BASER
# 3   2026-01-02        Contratos    499      PF             CRESOL SICOPER
# 4   2026-01-02        Contratos   6119      PF  CRESOL SICOPER CALLCENTER
# ..         ...              ...    ...     ...                        ...
# 457 2026-01-28  Carteira (CPFs)  36700  Unique                     Unique
# 458 2026-01-29        Contratos  54168  Unique                     Unique
# 459 2026-01-29  Carteira (CPFs)  36960  Unique                     Unique
# 460 2026-01-30        Contratos  54478  Unique                     Unique
# 461 2026-01-30  Carteira (CPFs)  37126  Unique                     Unique
#
#     MesAbreviado  nr_dia_util quartil  dt_mes         VALOR
# 0            Jan            1      Q1       1  1.324306e+06
# 1            Jan            1      Q1       1  1.835412e+07
# 2            Jan            1      Q1       1  1.431388e+09
# 3            Jan            1      Q1       1  3.614015e+07
# 4            Jan            1      Q1       1  1.086046e+08
# ..           ...          ...     ...     ...           ...
# 457          Jan           19      Q1       1  2.021624e+09
# 458          Jan           20      Q1       1  3.061251e+09
# 459          Jan           20      Q1       1  2.023576e+09
# 460          Jan           21      Q1       1  3.077002e+09
# 461          Jan           21      Q1       1  2.028187e+09
#
# [462 rows x 10 columns]

# %%
from utils.mailing.pipelines import processar_mailing_completo
from Cresol.src.mailing.data_processing import add_pf_pj, add_pa
from Cresol.src.config import LOG_MAILING, segmentacoes_extras

df_mailing_analitico, df_mailing_acumulado = processar_mailing_completo(
    df_mailing_hist,
    df_dw_calendario,
    segmentacoes=segmentacoes_extras,
    tratamentos_extras=[
        add_pf_pj,
        add_pa,
    ],
    arquivo_log=LOG_MAILING,
)
df_mailing_acumulado
# Out:
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 462
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 682
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 1,144
# ✓ Total de colunas: 11
# ============================================================
#            DATA        Indicador    qte   PF_PJ                         PA  \
# 0    2026-01-02        Contratos     97      PF              ASCOOB CRESOL
# 1    2026-01-02        Contratos    972      PF       CENTRAL BRASIL EXTRA
# 2    2026-01-02        Contratos  16630      PF               CRESOL BASER
# 3    2026-01-02        Contratos    499      PF             CRESOL SICOPER
# 4    2026-01-02        Contratos   6119      PF  CRESOL SICOPER CALLCENTER
# ...         ...              ...    ...     ...                        ...
# 1139 2026-01-29  Carteira (CPFs)  23642  Unique                     Unique
# 1140 2026-01-30        Contratos  32727  Unique                     Unique
# 1141 2026-01-30  Carteira (CPFs)  23140  Unique                     Unique
# 1142 2026-01-31        Contratos  32267  Unique                     Unique
# 1143 2026-01-31  Carteira (CPFs)  22805  Unique                     Unique
#
#      MesAbreviado  nr_dia_util quartil  dt_mes         VALOR   TIPO
# 0             Jan            1      Q1       1  1.324306e+06  Funil
# 1             Jan            1      Q1       1  1.835412e+07  Funil
# 2             Jan            1      Q1       1  1.431388e+09  Funil
# 3             Jan            1      Q1       1  3.614015e+07  Funil
# 4             Jan            1      Q1       1  1.086046e+08  Funil
# ...           ...          ...     ...     ...           ...    ...
# 1139          Jan           20      Q1       1  1.552664e+09  Daily
# 1140          Jan           21      Q1       1  2.325911e+09  Daily
# 1141          Jan           21      Q1       1  1.533384e+09  Daily
# 1142          N/A            0     N/A       0  2.290624e+09  Daily
# 1143          N/A            0     N/A       0  1.509900e+09  Daily
#
# [1144 rows x 11 columns]

# %%
df_mailing_analitico
#df_acumulado_mailing
#df_discagens_expert
print(df_acionamentos_analitico.columns)
# Out:
# Index(['DATA_ACIONA', 'HORA', 'CONTRATO_FIN', 'CPF_DEV', 'COD_ACIONA',
#        'DESC_ACIONAMENTO', 'COD_RECUP', 'NOME_RECUP', 'LOGIN_RECUP',
#        'ULTGRUPO_RECUP', 'VALORPRIN_FIN', 'STATCONT_FIN', 'DTDEVOL_FIN',
#        'DTENTRADA_FIN', 'CLASSIFICACAO_ACIONAMENTO', 'ACIONAMENTOS', 'CPC',
#        'CPCA', 'PROMESSA', 'DESCR', 'CPF', 'ID_CAR', 'ATRASO', 'VALOR',
#        'PF_PJ', 'PA', 'COD_CLI', 'nr_dia_util', 'quartil', 'dt_mes',
#        'mes_abreviado'],
#       dtype='object')

# %%
from Cresol.src.config import TRANSFORMACOES_DISCAGENS, LOG_DISCAGENS, segmentacoes_extras
from utils.discagens.expert.data_processing import aplicar_transformacoes_discagens

df_discagens_analitico, df_discagens_sem_relacionamento = aplicar_transformacoes_discagens(
    df=df_discagens_expert,
    config=TRANSFORMACOES_DISCAGENS,
    df_mailing=df_mailing_analitico,
    df_calendario=df_dw_calendario,
    segmentacoes_extras=segmentacoes_extras,
    arquivo_log=LOG_DISCAGENS,
)
df_discagens_analitico
# Out:
#               DATA  ID_DISCAGEM            CONTRATO AGENTE  DDD   TELEFONE  \
# 0       2026-01-05           15  500100820250081873          45  999239949
# 1       2026-01-05           26  500103820250221971          74  981015225
# 2       2026-01-05          136  500103820240957262          75  991897713
# 3       2026-01-05          210  500203320240346748          51  996799584
# 4       2026-01-05          246  500103820241676382          11  946080245
# ...            ...          ...                 ...    ...  ...        ...
# 965311  2026-01-30     49434253  500204420220017811          49  999940743
# 965312  2026-01-30     49434398  500103820241540273          75  999664096
# 965313  2026-01-30     49434614  500103820240230199          75   32722358
# 965314  2026-01-30     49435006  500204520220098842          55  999991519
# 965315  2026-01-30     49435216  500103820240691408          43  984154081
#
#          DATA_ENCERRAMENTO  CAMPANHA COD_SIP CLASS_RETORNO  ...  ATRASO  \
# 0      2026-01-05 09:47:04      4304     200         cxpos  ...    87.0
# 1      2026-01-05 09:47:04      4304     200         cxpos  ...    82.0
# 2      2026-01-05 09:47:09      4786     200         cxpre  ...  2294.0
# 3      1899-12-30 00:00:00      4304     408         cxpre  ...    83.0
# 4      1899-12-30 00:00:00      4786     480                ...  3511.0
# ...                    ...       ...     ...           ...  ...     ...
# 965311 1899-12-30 00:00:00      4786                 cxpre  ...    44.0
# 965312 2026-01-30 17:49:48      4786     200      silencio  ...  3152.0
# 965313 1899-12-30 00:00:00      4786     480                ...  6037.0
# 965314 1899-12-30 00:00:00      4786     408                ...    42.0
# 965315 1899-12-30 00:00:00      4786     480                ...  3566.0
#
#        COD_CLI      VALOR  PF_PJ                         PA          CPF  \
# 0        181.0   14166.63     PF               CRESOL BASER   4197996993
# 1        181.0   14934.00     PF               CRESOL BASER  94057427104
# 2        181.0   57401.89     PF               CRESOL BASER    730899586
# 3        230.0   13205.55     PF             CRESOL SICOPER  78685737087
# 4        181.0  112941.29     PF               CRESOL BASER  59253029587
# ...        ...        ...    ...                        ...          ...
# 965311   231.0     981.61     PF  CRESOL SICOPER CALLCENTER   6340726925
# 965312   181.0  146052.65     PF               CRESOL BASER  23989130587
# 965313   181.0   31475.54     PF               CRESOL BASER  58060278568
# 965314   231.0     936.60     PF  CRESOL SICOPER CALLCENTER  62458256015
# 965315   181.0  168884.20     PF               CRESOL BASER   5490266570
#
#         nr_dia_util quartil dt_mes mes_abreviado
# 0                 2      Q1      1           Jan
# 1                 2      Q1      1           Jan
# 2                 2      Q1      1           Jan
# 3                 2      Q1      1           Jan
# 4                 2      Q1      1           Jan
# ...             ...     ...    ...           ...
# 965311           21      Q1      1           Jan
# 965312           21      Q1      1           Jan
# 965313           21      Q1      1           Jan
# 965314           21      Q1      1           Jan
# 965315           21      Q1      1           Jan
#
# [914777 rows x 24 columns]

# %%
from Cresol.src.config import TRANSFORMACOES_DISCAGENS, LOG_DISCAGENS, segmentacoes_extras
from utils.discagens.expert.metricas_acumuladas import processar_acumulados_discagens_completo

df_discagens_acumulado = processar_acumulados_discagens_completo(
    df_discagens=df_discagens_analitico,
    segmentacoes_extras=segmentacoes_extras,
    retorno='consolidado',
    arquivo_log=LOG_DISCAGENS
)
df_discagens_acumulado
# Out:
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 240
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 240
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 480
# ✓ Total de colunas: 11
# ============================================================
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 480
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 480
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 960
# ✓ Total de colunas: 11
# ============================================================
#
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 1,440
# ✓ Total de colunas: 11
# ============================================================
#            DATA   Indicador    qte    PF_PJ                         PA  \
# 0    2026-01-05  Trabalhado     53       PF              ASCOOB CRESOL
# 1    2026-01-05  Trabalhado    426       PF       CENTRAL BRASIL EXTRA
# 2    2026-01-05  Trabalhado   7539       PF               CRESOL BASER
# 3    2026-01-05  Trabalhado    199       PF             CRESOL SICOPER
# 4    2026-01-05  Trabalhado    555       PF  CRESOL SICOPER CALLCENTER
# ...         ...         ...    ...      ...                        ...
# 1435 2026-01-28      Outros  31305  Esforço                    Esforço
# 1436 2026-01-29       ATIVO  13253  Esforço                    Esforço
# 1437 2026-01-29      Outros  31551  Esforço                    Esforço
# 1438 2026-01-30       ATIVO   6677  Esforço                    Esforço
# 1439 2026-01-30      Outros  35358  Esforço                    Esforço
#
#      MesAbreviado  nr_dia_util quartil  dt_mes         VALOR   TIPO
# 0             Jan            2      Q1       1  3.514587e+05  Funil
# 1             Jan            2      Q1       1  8.214105e+06  Funil
# 2             Jan            2      Q1       1  6.536391e+08  Funil
# 3             Jan            2      Q1       1  1.959359e+07  Funil
# 4             Jan            2      Q1       1  8.341752e+06  Funil
# ...           ...          ...     ...     ...           ...    ...
# 1435          Jan           19      Q1       1  2.266541e+09  Daily
# 1436          Jan           20      Q1       1  1.231196e+09  Daily
# 1437          Jan           20      Q1       1  2.252688e+09  Daily
# 1438          Jan           21      Q1       1  4.264689e+08  Daily
# 1439          Jan           21      Q1       1  2.499433e+09  Daily
#
# [1440 rows x 11 columns]

# %%
from Cresol.src.config import TRANSFORMACOES_DISCAGENS, LOG_DISCAGENS, segmentacoes_extras
from utils.discagens.expert.metricas_acumuladas import processar_acumulados_discagens

df_discagens_acumulado = processar_acumulados_discagens(
    df_discagens=df_discagens_analitico,
    segmentacoes=segmentacoes_extras,
    retorno='consolidado',
    arquivo_log=LOG_DISCAGENS
)
df_discagens_acumulado
# Out:
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 240
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 240
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 480
# ✓ Total de colunas: 11
# ============================================================
#           DATA   Indicador    qte    PF_PJ                         PA  \
# 0   2026-01-05  Trabalhado     53       PF              ASCOOB CRESOL
# 1   2026-01-05  Trabalhado    426       PF       CENTRAL BRASIL EXTRA
# 2   2026-01-05  Trabalhado   7539       PF               CRESOL BASER
# 3   2026-01-05  Trabalhado    199       PF             CRESOL SICOPER
# 4   2026-01-05  Trabalhado    555       PF  CRESOL SICOPER CALLCENTER
# ..         ...         ...    ...      ...                        ...
# 475 2026-01-26  Trabalhado  56687  Esforço                    Esforço
# 476 2026-01-27  Trabalhado  46481  Esforço                    Esforço
# 477 2026-01-28  Trabalhado  44294  Esforço                    Esforço
# 478 2026-01-29  Trabalhado  44804  Esforço                    Esforço
# 479 2026-01-30  Trabalhado  42035  Esforço                    Esforço
#
#     MesAbreviado  nr_dia_util quartil  dt_mes         VALOR   TIPO
# 0            Jan            2      Q1       1  3.514587e+05  Funil
# 1            Jan            2      Q1       1  8.214105e+06  Funil
# 2            Jan            2      Q1       1  6.536391e+08  Funil
# 3            Jan            2      Q1       1  1.959359e+07  Funil
# 4            Jan            2      Q1       1  8.341752e+06  Funil
# ..           ...          ...     ...     ...           ...    ...
# 475          Jan           17      Q1       1  1.752704e+09  Daily
# 476          Jan           18      Q1       1  3.157770e+09  Daily
# 477          Jan           19      Q1       1  2.971129e+09  Daily
# 478          Jan           20      Q1       1  3.483884e+09  Daily
# 479          Jan           21      Q1       1  2.925902e+09  Daily
#
# [480 rows x 11 columns]

# %%
from Cresol.src.config import LOG_DISCAGENS, segmentacoes_extras
from utils.discagens.expert.Ringing.metricas_acumuladas import processar_acumulados_ringing

# Retorno consolidado (um DataFrame único)
df_ringing_acumulados = processar_acumulados_ringing(
    df_discagens=df_discagens_analitico,
    segmentacoes=segmentacoes_extras,
    consolidado=True,
    arquivo_log=LOG_DISCAGENS,
)
df_ringing_acumulados
# Out:
# ============================================================
# ✓ 6 DataFrames unidos com sucesso
# ✓ Total de linhas: 480
# ✓ Total de colunas: 11
# ============================================================
#           DATA Indicador    qte    PF_PJ                         PA  \
# 0   2026-01-05   Ringing     36       PF              ASCOOB CRESOL
# 1   2026-01-05   Ringing    246       PF       CENTRAL BRASIL EXTRA
# 2   2026-01-05   Ringing   4988       PF               CRESOL BASER
# 3   2026-01-05   Ringing    103       PF             CRESOL SICOPER
# 4   2026-01-05   Ringing    387       PF  CRESOL SICOPER CALLCENTER
# ..         ...       ...    ...      ...                        ...
# 475 2026-01-26   Ringing  28245  Esforço                    Esforço
# 476 2026-01-27   Ringing  22471  Esforço                    Esforço
# 477 2026-01-28   Ringing  21566  Esforço                    Esforço
# 478 2026-01-29   Ringing  18545  Esforço                    Esforço
# 479 2026-01-30   Ringing   7872  Esforço                    Esforço
#
#     MesAbreviado  nr_dia_util quartil  dt_mes         VALOR   TIPO
# 0            Jan            2      Q1       1  2.270158e+05  Funil
# 1            Jan            2      Q1       1  4.936702e+06  Funil
# 2            Jan            2      Q1       1  4.577708e+08  Funil
# 3            Jan            2      Q1       1  7.136199e+06  Funil
# 4            Jan            2      Q1       1  5.759879e+06  Funil
# ..           ...          ...     ...     ...           ...    ...
# 475          Jan           17      Q1       1  1.021507e+09  Daily
# 476          Jan           18      Q1       1  1.572427e+09  Daily
# 477          Jan           19      Q1       1  1.463868e+09  Daily
# 478          Jan           20      Q1       1  1.517666e+09  Daily
# 479          Jan           21      Q1       1  5.054150e+08  Daily
#
# [480 rows x 11 columns]

# %%
from Cresol.src.config import LOG_DISCAGENS, segmentacoes_extras
from utils.discagens.expert.Ringing.metricas_acumuladas import processar_acumulados_atendidas

# Retorno consolidado (um DataFrame único)
df_ringing_acumulados = processar_acumulados_atendidas(
    df_discagens=df_discagens_analitico,
    segmentacoes=segmentacoes_extras,
    consolidado=True,
    arquivo_log=LOG_DISCAGENS,
)
df_ringing_acumulados

# %%
# Verificar o df antes do filtro
print(df_discagens_analitico[['DATA_ENCERRAMENTO', 'COD_SIP']].dtypes)
print()

# Verificar quantos registros passam em cada filtro
print("Total:", len(df_discagens_analitico))
print("COD_SIP == 200:", (df_discagens_analitico['COD_SIP'] == 200).sum())
print("DATA_ENCERRAMENTO != '1899-12-30':", (df_discagens_analitico['DATA_ENCERRAMENTO'].astype(str).str[:10] != '1899-12-30').sum())
print("Ambos:", len(df_discagens_analitico[
    (df_discagens_analitico['DATA_ENCERRAMENTO'].astype(str).str[:10] != '1899-12-30') &
    (df_discagens_analitico['COD_SIP'] == 200)
]))

# Verificar amostra dos valores reais
print()
print(df_discagens_analitico['DATA_ENCERRAMENTO'].value_counts().head())
print()
print(df_discagens_analitico['COD_SIP'].value_counts().head())
# Out:
# DATA_ENCERRAMENTO    datetime64[ns]
# COD_SIP                      object
# dtype: object
#
# Total: 914777
# COD_SIP == 200: 0
# DATA_ENCERRAMENTO != '1899-12-30': 427381
# Ambos: 0
#
# DATA_ENCERRAMENTO
# 1899-12-30 00:00:00    487396
# 2026-01-21 16:52:13        10
# 2026-01-14 11:27:20         8
# 2026-01-20 15:04:58         8
# 2026-01-19 09:55:02         8
# Name: count, dtype: int64
#
# COD_SIP
# 200    427381
# 480    210688
# 404    131424
# 408     77878
# 500     23267
# Name: count, dtype: int64

# %%
df_tab_acionamentos
df_sem_relacionamento
#df_sem_descricao
#df_tabulacao_aciona
# Out:
#       DATA_ACIONA      HORA        CONTRATO_FIN         CPF_DEV COD_ACIONA  \
# 0      2026-01-23  00:00:00  500300520180029319       808154052      11150
# 1      2026-01-29  00:00:00   10100500000043745      5169832966      11150
# 2      2026-01-29  00:00:00   10100800000040282      4803115958      11150
# 3      2026-01-15  00:00:00  500100520170005792      7166612924      11150
# 4      2026-01-15  00:00:00  500106120180006247      9806940946      11150
# ...           ...       ...                 ...             ...        ...
# 31313  2026-01-28  00:00:00  500200420230305143  43386084000156      11150
# 31315  2026-01-28  00:00:00  500200420240056546     11423511905      11150
# 31317  2026-01-15  00:00:00  500200420240085198      3921243432      11150
# 31320  2026-01-15  00:00:00  500200420240202397  43386084000156      11150
# 31321  2026-01-28  00:00:00  500200420240202397  43386084000156      11150
#
#             DESC_ACIONAMENTO COD_RECUP                  NOME_RECUP  \
# 0      ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# 1      ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# 2      ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# 3      ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# 4      ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# ...                      ...       ...                         ...
# 31313  ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# 31315  ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# 31317  ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# 31320  ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
# 31321  ENVIO DE RCS - CRESOL     18640  MARIA LUIZA MOREIRA ARAUJO
#
#          LOGIN_RECUP ULTGRUPO_RECUP  ...  ID_CAR ATRASO VALOR PF_PJ   PA  \
# 0      MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# 1      MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# 2      MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# 3      MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# 4      MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# ...              ...            ...  ...     ...    ...   ...   ...  ...
# 31313  MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# 31315  MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# 31317  MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# 31320  MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
# 31321  MARIAM.ARAUJO           None  ...     NaN    NaN   NaN   NaN  NaN
#
#       COD_CLI  nr_dia_util  quartil  dt_mes mes_abreviado
# 0         181         16.0       Q1     1.0           Jan
# 1         181         20.0       Q1     1.0           Jan
# 2         181         20.0       Q1     1.0           Jan
# 3         181         10.0       Q1     1.0           Jan
# 4         181         10.0       Q1     1.0           Jan
# ...       ...          ...      ...     ...           ...
# 31313     231         19.0       Q1     1.0           Jan
# 31315     231         19.0       Q1     1.0           Jan
# 31317     231         10.0       Q1     1.0           Jan
# 31320     231         10.0       Q1     1.0           Jan
# 31321     231         19.0       Q1     1.0           Jan
#
# [19363 rows x 26 columns]

# %%
from utils.acionamentos.metricas_acumuladas import processar_acumulados_acionamentos
from utils.acionamentos.data_processing import enriquecer_acionamentos, processar_acionamentos
from Cresol.src.config import TRANSFORMACOES_DISCAGENS, LOG_ACIONAMENTOS, segmentacoes_extras

df_acionamentos_analitico, df_acionamentos_sem_relacionamento, df_sem_descricao = processar_acionamentos(
    df_tab_acionamentos=df_tab_acionamentos,
    df_tabulacao_aciona=df_tabulacao_aciona,
    df_mailing_hist=df_mailing_analitico,
    df_dw_calendario=df_dw_calendario,
    segmentacoes_extras=segmentacoes_extras,
    arquivo_log=LOG_ACIONAMENTOS,
)
df_acionamentos_analitico
# Out:
#       DATA_ACIONA             HORA        CONTRATO_FIN         CPF_DEV  \
# 3245   2026-01-15         00:00:00  500100320230747586  12949342000131
# 3246   2026-01-16  10:08:50.346666  500100320230747586  12949342000131
# 3247   2026-01-26         00:00:00  500100320230747586  12949342000131
# 3248   2026-01-28         00:00:00  500100320230747586  12949342000131
# 3757   2026-01-26  15:19:32.826666  500106920210121159  10468893000158
# ...           ...              ...                 ...             ...
# 31664  2026-01-21  13:47:14.920000  500202720250083555      9278344990
# 31665  2026-01-30  13:22:47.520000  500202720250083555      9278344990
# 31666  2026-01-14  09:00:43.223333  500202720250097308      9278344990
# 31667  2026-01-21  13:47:14.943333  500202720250097308      9278344990
# 31668  2026-01-30  13:22:47.636666  500202720250097308      9278344990
#
#       COD_ACIONA                  DESC_ACIONAMENTO COD_RECUP  \
# 3245       11150             ENVIO DE RCS - CRESOL     18640
# 3246        5281             ENVIO DE WHATS - AÇÃO     12036
# 3247       11150             ENVIO DE RCS - CRESOL     18640
# 3248       11150             ENVIO DE RCS - CRESOL     18640
# 3757        5286    PROMESSA DE PAGAMENTO - CRESOL     12036
# ...          ...                               ...       ...
# 31664       5281             ENVIO DE WHATS - AÇÃO     12036
# 31665       5283  LINHA MUDA / NÃO ATENDE - CRESOL     12036
# 31666       5281             ENVIO DE WHATS - AÇÃO     12036
# 31667       5281             ENVIO DE WHATS - AÇÃO     12036
# 31668       5283  LINHA MUDA / NÃO ATENDE - CRESOL     12036
#
#                        NOME_RECUP    LOGIN_RECUP ULTGRUPO_RECUP  ...  ID_CAR  \
# 3245   MARIA LUIZA MOREIRA ARAUJO  MARIAM.ARAUJO           None  ...    89.0
# 3246      ANIELY OLIVEIRA DE LIMA      ANIELY_VV           OUZE  ...    89.0
# 3247   MARIA LUIZA MOREIRA ARAUJO  MARIAM.ARAUJO           None  ...    89.0
# 3248   MARIA LUIZA MOREIRA ARAUJO  MARIAM.ARAUJO           None  ...    89.0
# 3757      ANIELY OLIVEIRA DE LIMA      ANIELY_VV           OUZE  ...    89.0
# ...                           ...            ...            ...  ...     ...
# 31664     ANIELY OLIVEIRA DE LIMA      ANIELY_VV           OUZE  ...     NaN
# 31665     ANIELY OLIVEIRA DE LIMA      ANIELY_VV           OUZE  ...     NaN
# 31666     ANIELY OLIVEIRA DE LIMA      ANIELY_VV           OUZE  ...     NaN
# 31667     ANIELY OLIVEIRA DE LIMA      ANIELY_VV           OUZE  ...     NaN
# 31668     ANIELY OLIVEIRA DE LIMA      ANIELY_VV           OUZE  ...     NaN
#
#       ATRASO       VALOR PF_PJ                    PA  COD_CLI  nr_dia_util  \
# 3245    87.0  1270429.80    PJ          CRESOL BASER    181.0         10.0
# 3246    88.0  1270771.49    PJ          CRESOL BASER    181.0         11.0
# 3247    98.0  1171449.15    PJ          CRESOL BASER    181.0         17.0
# 3248   100.0  1289755.74    PJ          CRESOL BASER    181.0         19.0
# 3757   174.0     5252.44    PJ          CRESOL BASER    181.0         17.0
# ...      ...         ...   ...                   ...      ...          ...
# 31664  131.0     4332.39    PF  CENTRAL BRASIL EXTRA    254.0         14.0
# 31665  140.0     4363.57    PF  CENTRAL BRASIL EXTRA    254.0         21.0
# 31666   91.0     5293.77    PF  CENTRAL BRASIL EXTRA    254.0          9.0
# 31667   98.0     5436.05    PF  CENTRAL BRASIL EXTRA    254.0         14.0
# 31668  107.0     5465.21    PF  CENTRAL BRASIL EXTRA    254.0         21.0
#
#        quartil  dt_mes mes_abreviado
# 3245        Q1     1.0           Jan
# 3246        Q1     1.0           Jan
# 3247        Q1     1.0           Jan
# 3248        Q1     1.0           Jan
# 3757        Q1     1.0           Jan
# ...        ...     ...           ...
# 31664       Q1     1.0           Jan
# 31665       Q1     1.0           Jan
# 31666       Q1     1.0           Jan
# 31667       Q1     1.0           Jan
# 31668       Q1     1.0           Jan
#
# [12306 rows x 31 columns]

# %%
from utils.acionamentos.metricas_acumuladas import processar_acumulados_acionamentos
from Cresol.src.config import LOG_ACIONAMENTOS, segmentacoes_extras

df_acionamentos_acumulados = processar_acumulados_acionamentos(
    df_acionamentos=df_acionamentos_analitico,
    segmentacoes=segmentacoes_extras,
    retorno='consolidado',
    arquivo_log=LOG_ACIONAMENTOS
)
df_acionamentos_acumulados
# Out:
# ✓ DataFrame 1: Colunas renomeadas: DATA_ACIONA -> DATA
# ✓ DataFrame 2: Colunas renomeadas: DATA_ACIONA -> DATA
# ✓ DataFrame 3: Colunas renomeadas: DATA_ACIONA -> DATA
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 796
# ✓ Total de colunas: 10
# ============================================================
# ✓ DataFrame 1: Colunas renomeadas: DATA_ACIONA -> DATA
# ✓ DataFrame 2: Colunas renomeadas: DATA_ACIONA -> DATA
# ✓ DataFrame 3: Colunas renomeadas: DATA_ACIONA -> DATA
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 800
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 1,596
# ✓ Total de colunas: 11
# ============================================================
#            DATA     Indicador    qte    PF_PJ                         PA  \
# 0    2026-01-05  Acionamentos    5.0       PF       CENTRAL BRASIL EXTRA
# 1    2026-01-05  Acionamentos   80.0       PF               CRESOL BASER
# 2    2026-01-05  Acionamentos    8.0       PF  CRESOL SICOPER CALLCENTER
# 3    2026-01-05  Acionamentos   31.0       PJ               CRESOL BASER
# 4    2026-01-05  Acionamentos    4.0       PJ  CRESOL SICOPER CALLCENTER
# ...         ...           ...    ...      ...                        ...
# 1591 2026-01-30      Promessa   45.0  Esforço                    Esforço
# 1592 2026-01-31  Acionamentos  115.0  Esforço                    Esforço
# 1593 2026-01-31           CPC    0.0  Esforço                    Esforço
# 1594 2026-01-31          CPCA    0.0  Esforço                    Esforço
# 1595 2026-01-31      Promessa    0.0  Esforço                    Esforço
#
#      MesAbreviado  nr_dia_util quartil  dt_mes  VALORPRIN_FIN   TIPO
# 0             Jan            2      Q1       1       31096.82  Funil
# 1             Jan            2      Q1       1     2997270.97  Funil
# 2             Jan            2      Q1       1      199386.07  Funil
# 3             Jan            2      Q1       1     3528257.24  Funil
# 4             Jan            2      Q1       1      178843.54  Funil
# ...           ...          ...     ...     ...            ...    ...
# 1591          Jan           21      Q1       1     6279719.78  Daily
# 1592          N/A            0       0       0     2362725.37  Daily
# 1593          N/A            0       0       0           0.00  Daily
# 1594          N/A            0       0       0           0.00  Daily
# 1595          N/A            0       0       0           0.00  Daily
#
# [1596 rows x 11 columns]

# %%
df_sms,
df_rcs,
df_email
#df_whats
# Out:
# Empty DataFrame
# Columns: [DATA, CPF, PF_PJ]
# Index: []

# %%
from Cresol.src.config import LOG_CHANNELS, segmentacoes_extras
from utils.digital_channels.data_processing import processar_massivos

df_massivos_analitico, df_sem_relacionamento = processar_massivos(
    df_sms=df_sms,
    df_rcs=df_rcs,
    df_email=df_email,
    df_whats=df_whats,
    df_mailing_hist=df_mailing_analitico,
    df_dw_calendario=df_dw_calendario,
    segmentacoes_extras=segmentacoes_extras,
    arquivo_log=LOG_CHANNELS,
)
df_massivos_analitico
# Out:
#                   CPF        DATA CANAL            CONTRATO  ID_CAR  ATRASO  \
# 0      21719722000170  2026-01-05   SMS  500100320250629276    89.0    21.0
# 1         16257774004  2026-01-05   SMS  500106920230250327    89.0   174.0
# 2      50484132000104  2026-01-05   SMS  500100320251190575    89.0   116.0
# 3          3888716950  2026-01-05   SMS  500100920240400454    89.0    32.0
# 4          4942509920  2026-01-05   SMS  500106120250179411    89.0    26.0
# ...               ...         ...   ...                 ...     ...     ...
# 27223      5185253924  2026-01-30   RCS  500103120240305020    89.0    36.0
# 27224  40494634000162  2026-01-30   RCS  500103820241057096    89.0    66.0
# 27225      9347414689  2026-01-30   RCS  500109520250755572    89.0     7.0
# 27226     89450973920  2026-01-30   RCS  500300520250010926    89.0    15.0
# 27227      7410297905  2026-01-30   RCS  500104920250139592    89.0    20.0
#
#        COD_CLI     VALOR PF_PJ            PA  nr_dia_util quartil  dt_mes  \
# 0        181.0  80423.10    PJ  CRESOL BASER          2.0      Q1     1.0
# 1        181.0  78202.26    PF  CRESOL BASER          2.0      Q1     1.0
# 2        181.0  12971.56    PJ  CRESOL BASER          2.0      Q1     1.0
# 3        181.0  80145.31    PF  CRESOL BASER          2.0      Q1     1.0
# 4        181.0  80108.04    PF  CRESOL BASER          2.0      Q1     1.0
# ...        ...       ...   ...           ...          ...     ...     ...
# 27223    181.0    824.73    PF  CRESOL BASER         21.0      Q1     1.0
# 27224    181.0   2295.81    PJ  CRESOL BASER         21.0      Q1     1.0
# 27225    181.0   3087.40    PF  CRESOL BASER         21.0      Q1     1.0
# 27226    181.0  10227.57    PF  CRESOL BASER         21.0      Q1     1.0
# 27227    181.0  40652.67    PF  CRESOL BASER         21.0      Q1     1.0
#
#       mes_abreviado
# 0               Jan
# 1               Jan
# 2               Jan
# 3               Jan
# 4               Jan
# ...             ...
# 27223           Jan
# 27224           Jan
# 27225           Jan
# 27226           Jan
# 27227           Jan
#
# [27228 rows x 14 columns]

# %%
from utils.digital_channels.metricas_acumuladas import processar_acumulados_massivos
from Cresol.src.config import LOG_CHANNELS, segmentacoes_extras

# Retorno consolidado com coluna TIPO
df_massivos_acumulado = processar_acumulados_massivos(
    df_massivos=df_massivos_analitico,
    segmentacoes=segmentacoes_extras,
    arquivo_log=LOG_CHANNELS
)
df_massivos_acumulado
# Out:
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 315
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 228
# ✓ Total de colunas: 10
# ============================================================
#
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 543
# ✓ Total de colunas: 11
# ============================================================
#           DATA Indicador   qte    PF_PJ                         PA  \
# 0   2026-01-02       RCS  1494       PF               CRESOL BASER
# 1   2026-01-02       RCS     1       PF  CRESOL SICOPER CALLCENTER
# 2   2026-01-02       RCS   348       PJ               CRESOL BASER
# 3   2026-01-02       SMS   883       PF               CRESOL BASER
# 4   2026-01-05       RCS  2972       PF               CRESOL BASER
# ..         ...       ...   ...      ...                        ...
# 538 2026-01-27       SMS   122  Esforço                    Esforço
# 539 2026-01-28       RCS   486  Esforço                    Esforço
# 540 2026-01-29       SMS  1711  Esforço                    Esforço
# 541 2026-01-30       RCS   199  Esforço                    Esforço
# 542 2026-01-31       SMS    72  Esforço                    Esforço
#
#     MesAbreviado  nr_dia_util quartil  dt_mes  VALORPRIN_FIN   TIPO
# 0            Jan          1.0      Q1     1.0   1.263103e+07  Funil
# 1            Jan          1.0      Q1     1.0   2.340360e+03  Funil
# 2            Jan          1.0      Q1     1.0   4.126341e+06  Funil
# 3            Jan          1.0      Q1     1.0   9.621171e+07  Funil
# 4            Jan          2.0      Q1     1.0   1.146828e+08  Funil
# ..           ...          ...     ...     ...            ...    ...
# 538          Jan         18.0      Q1     1.0   6.606238e+06  Daily
# 539          Jan         19.0      Q1     1.0   1.339197e+08  Daily
# 540          Jan         20.0      Q1     1.0   7.194221e+07  Daily
# 541          Jan         21.0      Q1     1.0   1.754917e+07  Daily
# 542          N/A          0.0       0     0.0   1.666100e+06  Daily
#
# [543 rows x 11 columns]

# %%
df_massivos_acumulado
# Out:
#           DATA Indicador   qte    PF_PJ                         PA  \
# 0   2026-01-02       RCS  1494       PF               CRESOL BASER
# 1   2026-01-02       RCS     1       PF  CRESOL SICOPER CALLCENTER
# 2   2026-01-02       RCS   348       PJ               CRESOL BASER
# 3   2026-01-02       SMS   883       PF               CRESOL BASER
# 4   2026-01-05       RCS  2972       PF               CRESOL BASER
# ..         ...       ...   ...      ...                        ...
# 538 2026-01-27       SMS   122  Esforço                    Esforço
# 539 2026-01-28       RCS   486  Esforço                    Esforço
# 540 2026-01-29       SMS  1711  Esforço                    Esforço
# 541 2026-01-30       RCS   199  Esforço                    Esforço
# 542 2026-01-31       SMS    72  Esforço                    Esforço
#
#     MesAbreviado  nr_dia_util quartil  dt_mes  VALORPRIN_FIN   TIPO
# 0            Jan          1.0      Q1     1.0   1.263103e+07  Funil
# 1            Jan          1.0      Q1     1.0   2.340360e+03  Funil
# 2            Jan          1.0      Q1     1.0   4.126341e+06  Funil
# 3            Jan          1.0      Q1     1.0   9.621171e+07  Funil
# 4            Jan          2.0      Q1     1.0   1.146828e+08  Funil
# ..           ...          ...     ...     ...            ...    ...
# 538          Jan         18.0      Q1     1.0   6.606238e+06  Daily
# 539          Jan         19.0      Q1     1.0   1.339197e+08  Daily
# 540          Jan         20.0      Q1     1.0   7.194221e+07  Daily
# 541          Jan         21.0      Q1     1.0   1.754917e+07  Daily
# 542          N/A          0.0       0     0.0   1.666100e+06  Daily
#
# [543 rows x 11 columns]

# %%
import traceback

from utils.utils import salvar_log, registrar_tempo, unir_dataframes
from Cresol.src.database import inserir_acumulado
from utils.db_connection import get_db_connections
from Cresol.src.config import LOG_PIPELINE

def _executar_etapa(nome: str, fn, *args, **kwargs):
    """
    Executa uma etapa da pipeline com log padronizado.
    Lança a exceção original em caso de falha para interromper o fluxo.
    """
    salvar_log(f"{'─' * 50}", LOG_PIPELINE)
    salvar_log(f"INÍCIO » {nome}", LOG_PIPELINE)
    try:
        resultado = fn(*args, **kwargs)
        salvar_log(f"OK    » {nome}", LOG_PIPELINE)
        return resultado
    except Exception as e:
        salvar_log(f"FALHA » {nome}: {str(e)}", LOG_PIPELINE)
        salvar_log(traceback.format_exc(), LOG_PIPELINE)
        raise

df_acumulados_consolidado = _executar_etapa(
        "Consolidação dos acumulados",
        unir_dataframes,
        df_mailing_acumulado,
        df_discagens_acumulado,
        df_ringing_acumulados,
        df_acionamentos_acumulados,
        df_massivos_acumulado,
    )

with get_db_connections() as (_, conn_bd2, __):
    _executar_etapa(
        "Insert banco de dados",
        inserir_acumulado,
        df_acionamentos_acumulados,
        conn_bd2,
    )
df_acumulados_consolidado
# Out:
# ✓ DataFrame 4: Colunas renomeadas: VALORPRIN_FIN -> VALOR
# ✓ DataFrame 5: Colunas renomeadas: VALORPRIN_FIN -> VALOR
#
# ============================================================
# ✓ 5 DataFrames unidos com sucesso
# ✓ Total de linhas: 5,203
# ✓ Total de colunas: 11
# ============================================================
# 🔌 Conectando aos bancos de dados...
# ✅ Conexões estabelecidas
# 🔌 Conexão TRC fechada
# 🔌 Conexão BD2 fechada
# 🔌 Conexão SRC fechada
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[257], line 35
#      24 df_acumulados_consolidado = _executar_etapa(
#      25         "Consolidação dos acumulados",
#      26         unir_dataframes,
#    (...)     31         df_massivos_acumulado,
#      32     )
#      34 with get_db_connections() as (_, conn_bd2, __):
# ---> 35     _executar_etapa(
#      36         "Insert banco de dados",
#      37         inserir_acumulado,
#      38         df_acionamentos_acumulados,
#      39         conn_bd2,
#      40     )
#      41 df_acumulados_consolidado
#
# Cell In[257], line 16, in _executar_etapa(nome, fn, *args, **kwargs)
#      14 salvar_log(f"INÍCIO » {nome}", LOG_PIPELINE)
#      15 try:
# ---> 16     resultado = fn(*args, **kwargs)
#      17     salvar_log(f"OK    » {nome}", LOG_PIPELINE)
#      18     return resultado
#
# File ~\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\Cresol\src\database.py:15, in inserir_acumulado(df, conn, arquivo_log)
#      12     salvar_log(msg, arquivo_log)
#      13     return False
# ---> 15 df = df[list(COLUNAS_SINTETICO.keys())].rename(columns=COLUNAS_SINTETICO)
#      17 return inserir_dataframe(
#      18     df=df,
#      19     tabela=TABELA_SINTETICO,
#    (...)     22     arquivo_log=arquivo_log,
#      23 )
#
# File c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\.venv\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\.venv\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\.venv\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['VALOR'] not in index"

# %%
print(df_acumulados_consolidado.columns)
# Out:
# Index(['DATA', 'Indicador', 'qte', 'PF_PJ', 'PA', 'MesAbreviado',
#        'nr_dia_util', 'quartil', 'dt_mes', 'VALOR', 'TIPO'],
#       dtype='object')

# %%
import importlib
import utils._database.insert
importlib.reload(utils._database.insert)

# teste direto no df antes de qualquer função
registro_teste = [tuple(row) for row in df_acionamentos_acumulados.head(1).itertuples(index=False, name=None)]
for i_val, val in enumerate(registro_teste[0]):
    print(f"param-index={i_val} | valor={val} | tipo={type(val)}")
# Out:
# param-index=0 | valor=2026-01-05 00:00:00 | tipo=<class 'pandas._libs.tslibs.timestamps.Timestamp'>
# param-index=1 | valor=Acionamentos | tipo=<class 'str'>
# param-index=2 | valor=5.0 | tipo=<class 'float'>
# param-index=3 | valor=PF | tipo=<class 'str'>
# param-index=4 | valor=CENTRAL BRASIL EXTRA | tipo=<class 'str'>
# param-index=5 | valor=Jan | tipo=<class 'str'>
# param-index=6 | valor=2 | tipo=<class 'int'>
# param-index=7 | valor=Q1 | tipo=<class 'str'>
# param-index=8 | valor=1 | tipo=<class 'int'>
# param-index=9 | valor=31096.82 | tipo=<class 'float'>
# param-index=10 | valor=Funil | tipo=<class 'str'>

# %%
df_acumulados_consolidado = _executar_etapa(
        "Consolidação dos acumulados",
        unir_dataframes,
        df_mailing_acumulado,
        df_discagens_acumulado,
        df_ringing_acumulados,
        df_acionamentos_acumulados,
        df_massivos_acumulado,
    )
df_acumulados_consolidado
# Out:
# ✓ DataFrame 4: Colunas renomeadas: VALORPRIN_FIN -> VALOR
# ✓ DataFrame 5: Colunas renomeadas: VALORPRIN_FIN -> VALOR
#
# ============================================================
# ✓ 5 DataFrames unidos com sucesso
# ✓ Total de linhas: 5,203
# ✓ Total de colunas: 11
# ============================================================
#            DATA  Indicador      qte    PF_PJ                         PA  \
# 0    2026-01-02  Contratos     97.0       PF              ASCOOB CRESOL
# 1    2026-01-02  Contratos    972.0       PF       CENTRAL BRASIL EXTRA
# 2    2026-01-02  Contratos  16630.0       PF               CRESOL BASER
# 3    2026-01-02  Contratos    499.0       PF             CRESOL SICOPER
# 4    2026-01-02  Contratos   6119.0       PF  CRESOL SICOPER CALLCENTER
# ...         ...        ...      ...      ...                        ...
# 5198 2026-01-27        SMS    122.0  Esforço                    Esforço
# 5199 2026-01-28        RCS    486.0  Esforço                    Esforço
# 5200 2026-01-29        SMS   1711.0  Esforço                    Esforço
# 5201 2026-01-30        RCS    199.0  Esforço                    Esforço
# 5202 2026-01-31        SMS     72.0  Esforço                    Esforço
#
#      MesAbreviado  nr_dia_util quartil  dt_mes         VALOR   TIPO
# 0             Jan          1.0      Q1     1.0  1.324306e+06  Funil
# 1             Jan          1.0      Q1     1.0  1.835412e+07  Funil
# 2             Jan          1.0      Q1     1.0  1.431388e+09  Funil
# 3             Jan          1.0      Q1     1.0  3.614015e+07  Funil
# 4             Jan          1.0      Q1     1.0  1.086046e+08  Funil
# ...           ...          ...     ...     ...           ...    ...
# 5198          Jan         18.0      Q1     1.0  6.606238e+06  Daily
# 5199          Jan         19.0      Q1     1.0  1.339197e+08  Daily
# 5200          Jan         20.0      Q1     1.0  7.194221e+07  Daily
# 5201          Jan         21.0      Q1     1.0  1.754917e+07  Daily
# 5202          N/A          0.0       0     0.0  1.666100e+06  Daily
#
# [5203 rows x 11 columns]

# %%
import importlib
import utils._database.insert
import Cresol.src.database

importlib.reload(utils._database.insert)
importlib.reload(Cresol.src.database)

from Cresol.src.database import inserir_acumulado, COLUNAS_SINTETICO

with get_db_connections() as (_, conn_bd2, __):
    inserir_acumulado(df_acumulados_consolidado, conn_bd2)
# Out:
# 🔌 Conectando aos bancos de dados...
# ✅ Conexões estabelecidas
# ───────────────────────────────────────────────────────
# [sintetico_cresol] Iniciando insert — 5,203 registros em 1 lote(s)
# [sintetico_cresol] Lote 1/1 inserido — 5,203 registros
# [sintetico_cresol] ✅ Commit realizado — 5,203 registros inseridos com sucesso
# 🔌 Conexão TRC fechada
# 🔌 Conexão BD2 fechada
# 🔌 Conexão SRC fechada

# %%
import os
# #df_conflitos_score
#df_acionamentos_enriquecido_limpo, df_acion_semFaixa, df_acion_semDescricao, df_acion_semOrigem 
df_mailing_acumulado.to_csv('df_mailing_acumulado.csv', sep=';', index=False, decimal=',', encoding='utf-8-sig')
os.startfile('df_mailing_acumulado.csv')  # abre com o programa padrão
