# %%
import sys
from pathlib import Path

# Adiciona a pasta Projects ao path
projects_path = Path.cwd().parent  # Sobe para Projects/
sys.path.insert(0, str(projects_path))

# Agora os imports funcionarão
# from Getnet.src.data_wrangling_mailingHist import tratar_base_mailing_hist
from utils.db_connection import get_connection
from utils.queries import (
    get_query_discagens, 
    get_query_cad_devf, 
    get_query_mailing_hist, 
    get_query_tabulacao_aciona, 
    get_query_base_acionamentos, 
    get_query_dw_calendario, 
    get_query_pagamentos, 
    get_query_acordos
)

import pandas as pd
# DISCAGENS EXPERT
where_campanhas_getnet = "A.GrupoPrincipal IN (SELECT G.id_grupo FROM grupo G WHERE G.ID_CAMPANHA IN (19, 30))"
#MAILING_HIST
where_clientes_mailing = "COD_CLI IN(196,198,228)"
# ACIONAMENTOS
where_original = """((C.COD_CLI = 198 AND C.COD_CAR IN (1, 2, 3)) 
                     OR (C.COD_CLI = 196 AND C.COD_CAR IN (1, 3, 4)) 
                     OR (C.COD_CLI = 228 AND C.COD_CAR = 2))"""
# PAGAMENTOS
where_clientes_pagamentos = "B.COD_CLI IN(198, 196, 228)"
# ACORDOS
where_clientes_acordos = "B.COD_CLI IN(198, 196, 228)"

conn_src = get_connection("SERVER_SRC", "DATABASE_SRC")
conn_bd2 = get_connection("SERVER_BD2", "DATABASE_BD2")

df_discagens_expert = pd.read_sql(
    get_query_discagens('2025-12-01', '2025-12-01', where_campanhas_getnet),
    conn_src
)
df_maling_hist = pd.read_sql(
    get_query_mailing_hist('2025-12-01', '2025-12-31', where_clientes_mailing), 
    conn_bd2
)
df_tab_acionamentos = pd.read_sql(
    get_query_base_acionamentos('2025-12-01', '2025-12-31', where_original), 
    conn_src
)
df_dw_calendario = pd.read_sql(
    get_query_dw_calendario(), 
    conn_bd2
)
df_pagamentos = pd.read_sql(
    get_query_pagamentos('2025-12-01', '2025-12-31', where_clientes_pagamentos), 
    conn_src
)
df_acordos = pd.read_sql(
    get_query_acordos('2025-12-01', '2025-12-31', where_clientes_acordos), 
    conn_src
)
df_discagens_expert
# Out:
# C:\Users\claudiano.alves\AppData\Local\Temp\ipykernel_25108\1780127593.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_discagens_expert = pd.read_sql(
#               DATA        id    CONTRATO             CPF  ddd       fone  \
# 0       2025-12-01        10                               71  993132020
# 1       2025-12-01       249                               13  991056552
# 2       2025-12-01       254                               13  991056552
# 3       2025-12-01       258                               13  991056552
# 4       2025-12-01       268                               13  991056552
# ...            ...       ...         ...             ...  ...        ...
# 870123  2025-12-31  47017053  35924557id     48136565104   67  991084080
# 870124  2025-12-31  47017057  43183958id  47421344000138   12  996485056
# 870125  2025-12-31  47017059  40692451id  30664131000134   96  999128843
# 870126  2025-12-31  47017061  40749305id     36654372883   15  997879078
# 870127  2025-12-31  47017063  35951050id  35740270000113   83  998963992
#
#         GrupoPrincipal UltCodSigRecPublica ResultadoClassificacao  \
# 0                 4017
# 1                 4022
# 2                 4022
# 3                 4022
# 4                 4022
# ...                ...                 ...                    ...
# 870123            4047                 408                  cxpre
# 870124            4047                 200                  cxpre
# 870125            4047                 200                  cxpre
# 870126            4047                 200                  cxpre
# 870127            4047                 200                  cxpre
#
#           MotivoEncerramentoBilhete    Instante200OKPub        Agente  \
# 0       desligamentorecebidocliente 2025-12-01 07:49:43  bruno.curuca
# 1       desligamentorecebidocliente 1899-12-30 00:00:00  bruno.curuca
# 2       desligamentorecebidocliente 1899-12-30 00:00:00  bruno.curuca
# 3       desligamentorecebidocliente 1899-12-30 00:00:00  bruno.curuca
# 4       desligamentorecebidocliente 1899-12-30 00:00:00  bruno.curuca
# ...                             ...                 ...           ...
# 870123             bloqueiodetector 1899-12-30 00:00:00
# 870124             bloqueiodetector 2025-12-31 16:03:03
# 870125             bloqueiodetector 2025-12-31 16:03:02
# 870126             bloqueiodetector 2025-12-31 16:03:10
# 870127             bloqueiodetector 2025-12-31 16:03:13
#
#         tempoconversacao_ms codtabulacao
# 0                    302463         None
# 1                         0         None
# 2                         0         None
# 3                         0         None
# 4                         0         None
# ...                     ...          ...
# 870123                    0         None
# 870124                    0         None
# 870125                    0         None
# 870126                    0         None
# 870127                    0         None
#
# [870128 rows x 14 columns]

# %%
import os
# #df_conflitos_score
#df_acionamentos_enriquecido_limpo, df_acion_semFaixa, df_acion_semDescricao, df_acion_semOrigem 
df_PAYJOY.to_csv('df_PAYJOY.csv', sep=';', index=False, decimal=',', encoding='utf-8-sig')
os.startfile('df_PAYJOY.csv')  # abre com o programa padrão

# %%
# %load_ext autoreload
# %autoreload 2

import sys 
sys.path.append("..")

# %%
# sobe para Projects 
from Getnet.src.data_loader import load_data_getnet

dados = load_data_getnet('2025-12-01', '2025-12-31')

(
df_discagens_expert, 
df_mailing_hist, 
df_tab_acionamentos, 
df_tabulacao_aciona,
df_dw_calendario, 
df_pagamentos, 
df_acordos, 
df_sms,
df_rcs,
df_email,
df_telefones,
df_blacklist_expert
) = dados
