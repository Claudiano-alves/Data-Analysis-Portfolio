# %%
import os
# #df_conflitos_score
#df_acionamentos_enriquecido_limpo, df_acion_semFaixa, df_acion_semDescricao, df_acion_semOrigem 
resultado_final.to_csv('resultado_final.csv', sep=';', index=False, decimal=',', encoding='utf-8-sig')
os.startfile('resultado_final.csv')  # abre com o programa padrão
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 4
#       1 import os
#       2 # #df_conflitos_score
#       3 #df_acionamentos_enriquecido_limpo, df_acion_semFaixa, df_acion_semDescricao, df_acion_semOrigem
# ----> 4 resultado_final.to_csv('resultado_final.csv', sep=';', index=False, decimal=',', encoding='utf-8-sig')
#       5 os.startfile('resultado_final.csv')  # abre com o programa padrão
#
# AttributeError: 'dict' object has no attribute 'to_csv'

# %%
# %load_ext autoreload
# %autoreload 2

import sys 
sys.path.append("..")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import importlib 
# from Getnet.src import data_wrangling_mailingHist, utils, data_wrangling_pagamentos, data_wrangling_acordos, data_wrangling_acionamentos#, data_loader
from Getnet.src import data_loader, config
#from Getnet.src.acionamentos import data_processing, pipelines
from Getnet.src.consolidacao import pipelines
#from Getnet.src.pagamentos import data_processing, metricas_acumuladas
from utils import utils

# importlib.reload(data_loader)
# importlib.reload(queries)
# importlib.reload(data_wrangling_mailingHist)
# #importlib.reload(queries)
# importlib.reload(utils)
# importlib.reload(data_wrangling_pagamentos)
# importlib.reload(data_wrangling_acordos)
#importlib.reload(data_processing)
#importlib.reload(metricas_acumuladas)
importlib.reload(pipelines)
#importlib.reload(utils)
importlib.reload(data_loader)
# Out:
# <module 'Getnet.src.data_loader' from 'C:\\Users\\claudiano.alves\\Documents\\Claudiano\\repository\\Data-Analysis-Portfolio\\Projects\\Getnet\\src\\data_loader.py'>

# %%
import sys
# Remover módulos em cache
for mod_name in list(sys.modules.keys()):
    if 'Getnet' in mod_name or 'pagamentos' in mod_name:
        del sys.modules[mod_name]

# Agora importar novamente (vai carregar os arquivos atualizados)
from Getnet.src.consolidacao.pipelines import executar_pipeline_funil_completo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       5         del sys.modules[mod_name]
#       7 # Agora importar novamente (vai carregar os arquivos atualizados)
# ----> 8 from Getnet.src.consolidacao.pipelines import executar_pipeline_funil_completo
#
# ModuleNotFoundError: No module named 'Getnet'

# %%
# sobe para Projects 
from Getnet.src.consolidacao.data_loader_pipeline import carregar_dados_paralelo

dados = carregar_dados_paralelo('2026-01-01', '2026-01-31')

(
df_discagens_expert, 
df_mailing_hist, 
df_tab_acionamentos, 
df_tabulacao_aciona,
df_dw_calendario, 
df_pagamentos, 
df_acordos, 
# df_sms,
# df_rcs,
# df_email,
# df_telefones,
) = dados

# %%
# sobe para Projects 
from Getnet.src.data_loader import load_data_getnet

dados = load_data_getnet('2026-01-01', '2026-01-31')

(
df_discagens_expert, 
df_mailing_hist, 
df_tab_acionamentos, 
df_tabulacao_aciona,
df_dw_calendario, 
df_pagamentos, 
df_acordos, 
# df_sms,
# df_rcs,
# df_email,
# df_telefones,
) = dados
# Out:
# 🔌 Conectando aos bancos de dados...
# ✅ Conexões estabelecidas
#
# 📊 Carregando dados de 2026-01-01 até 2026-01-31...
# C:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\utils\data_loader.py:521: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conexao)
# [1/7] ✓ Discagens Expert: 866.272 registros (4m 9s)
# [2/7] ✓ Mailing Histórico: 3.924.991 registros (3m 15s)
# [3/7] ✓ Tabulação de Acionamentos: 2.730 registros (4m 4s)
# [4/7] ✓ Tabulação Acionamentos: 79 registros (0s)
# [5/7] ✓ Calendário: 21 registros (0s)
# [6/7] ✓ Pagamentos: 28.929 registros (3s)
# [7/7] ✓ Acordos: 3.917 registros (2s)
#
# ✅ Carregamento concluído em 11m 35s
# 🔌 Conexão TRC fechada
# 🔌 Conexão BD2 fechada
# 🔌 Conexão SRC fechada

# %%
# Desempacotar os VALORES do dicionário
(
df_discagens_expert, 
df_mailing_hist, 
df_tab_acionamentos, 
df_tabulacao_aciona, 
df_dw_calendario, 
df_pagamentos, 
df_acordos
) = dados.values()

# %%
# import sys, os
# repo_root = r"C:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio"
# projects_path = os.path.join(repo_root, "Projects")
# if projects_path not in sys.path:
#     sys.path.insert(0, projects_path)
# print("added to sys.path:", sys.path[0])

from Getnet.src.acionamentos.pipelines import acionamentos_humano
from Getnet.src.mailing.pipelines import processar_mailing_completo


df_mailing_tratado, df_mailing_final = processar_mailing_completo(df_mailing_hist, df_dw_calendario)
df_acionamentos = df_tab_acionamentos.copy()
df_tabulacao_acionamentos = df_tabulacao_aciona.copy()

df_acionamentos_humano, df_analitico_acionamentos_humano, df_acion_semFaixa_humano, df_acion_semDescricao_humano,df_acion_semOrigem_humano = acionamentos_humano(df_acionamentos, df_tabulacao_acionamentos, df_dw_calendario, df_mailing_tratado)
# Out:
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 418
# ✓ Total de colunas: 9
# ============================================================
# ✓ DataFrame 1: Colunas renomeadas: DATA_ACIONA -> DATA
# ✓ DataFrame 2: Colunas renomeadas: DATA_ACIONA -> DATA
# ✓ DataFrame 3: Colunas renomeadas: DATA_ACIONA -> DATA
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 570
# ✓ Total de colunas: 17
# ============================================================

# %%
df_mailing_hist
# Out:
#                DATA    CONTRATO             CPF  ATRASO  COD_CLI  COD_CAR  \
# 0        2026-01-01  48682558ID   4354792000153     146      228        2
# 1        2026-01-01  49606713ID  39855868000109      54      228        2
# 2        2026-01-01  33062010ID  39665220000170     414      228        2
# 3        2026-01-01  55041924ID     54372755520     268      228        2
# 4        2026-01-01  36196296ID     34326596287     445      228        2
# ...             ...         ...             ...     ...      ...      ...
# 3924986  2026-01-30  36464899ID     84869399504     845      228        2
# 3924987  2026-01-30  41978065ID     13793074730     595      228        2
# 3924988  2026-01-30  53179449ID  18649524000173      53      228        2
# 3924989  2026-01-30  50493209ID  23266996000187     144      228        2
# 3924990  2026-01-30  47525546ID     43853471587     443      228        2
#
#            VALOR
# 0         193.38
# 1          79.90
# 2        1343.78
# 3          55.80
# 4         461.79
# ...          ...
# 3924986   484.83
# 3924987   621.11
# 3924988    29.90
# 3924989    49.19
# 3924990    40.86
#
# [3924991 rows x 7 columns]

# %%
import sys
import os

# Obter o caminho raiz do Projects (onde o notebook está dentro)
notebook_dir = os.getcwd()
projects_root = os.path.dirname(os.path.dirname(notebook_dir))  # sobe 2 níveis de notebooks/

# Garantir que Projects está no sys.path para que "from Projects.x" funcione
if projects_root not in sys.path:
    sys.path.insert(0, projects_root)

print(f"✓ Projects path adicionado ao sys.path: {projects_root}")
print(f"  sys.path[0]: {sys.path[0]}")
# Out:
# ✓ Projects path adicionado ao sys.path: c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio
#   sys.path[0]: c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio

# %%
from Getnet.src.consolidacao.pipelines import executar_pipeline_funil_completo

resultado_final = executar_pipeline_funil_completo(
    df_tab_acionamentos, 
    df_tabulacao_aciona, 
    df_mailing_hist, 
    df_dw_calendario, 
    df_pagamentos, 
    df_acordos,
    df_discagens_expert
)
# Out:
# ============================================================
# ✓ 2 DataFrames unidos com sucesso
# ✓ Total de linhas: 440
# ✓ Total de colunas: 9
# ============================================================
# ✓ DataFrame 1: Colunas renomeadas: DATA_ACIONA -> DATA
# ✓ DataFrame 2: Colunas renomeadas: DATA_ACIONA -> DATA
# ✓ DataFrame 3: Colunas renomeadas: DATA_ACIONA -> DATA
#
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 600
# ✓ Total de colunas: 17
# ============================================================
# INFO:Projects.utils.utils:Diretório verificado/criado: \\trc-dc-ad\Planejamento\MIS\CARTEIRAS\GetNet\Analíticos\pagamentos
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 738
# ✓ Total de colunas: 10
# ============================================================
# INFO:Projects.utils.utils:Arquivo antigo removido: df_pagamentos_analitico_202602_20260203_120445.csv
# INFO:Projects.utils.utils:✓ Salvo: df_pagamentos_analitico_202602_20260203_130025.csv (741 linhas)
# INFO:Projects.utils.utils:Arquivo antigo removido: df_pagamentos_sem_fx_atraso_202602_20260203_120445.csv
# INFO:Projects.utils.utils:✓ Salvo: df_pagamentos_sem_fx_atraso_202602_20260203_130025.csv (85 linhas)
# INFO:Projects.utils.utils:
# ============================================================
# INFO:Projects.utils.utils:Resumo: 2/2 arquivos salvos com sucesso
# INFO:Projects.utils.utils:============================================================
# INFO:Projects.utils.utils:Diretório verificado/criado: \\trc-dc-ad\Planejamento\MIS\CARTEIRAS\GetNet\Analíticos\discagens
# ============================================================
# ✓ 3 DataFrames unidos com sucesso
# ✓ Total de linhas: 600
# ✓ Total de colunas: 17
# ============================================================

# %%
import os

# acessa o DataFrame dentro do dicionário
df_consolidado = resultado_final['consolidado'] 

# exporta para CSV
df_consolidado.to_csv('resultado_final.csv', sep=';', index=False, decimal=',', encoding='utf-8-sig')

# abre o arquivo com o programa padrão
os.startfile('resultado_final.csv')

# %%
resultado_final.keys()
# Out:
# dict_keys(['mailing', 'acionamentos', 'acionamentos_analitico', 'pagamentos', 'pagamentos_analitico', 'consolidado'])
