# %%
from Estácio.process_digital_channels.utils.queries import get_query_mailing_hist

df_mailing_hist = get_query_mailing_hist(dt_ini='2024-01-01', dt_fim='2024-12-31', where_clause="M.COD_CLI = 252")
