# %%
# %load_ext autoreload
# %autoreload 2

import sys 
sys.path.append("..")

# %%
# sobe para Projects 
from Ouze.src.data_loader import load_data_ouze

dados = load_data_ouze('2025-12-01', '2025-12-31')

(
df_discagens_expert, 
df_mailing_hist, 
df_tab_acionamentos, 
df_tabulacao_aciona,
df_dw_calendario, 
df_pagamentos, 
df_acordos, 
df_sms,
df_rcs,
df_email,
df_telefones,
df_blacklist_expert
) = dados
# Out:
# c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\notebooks\..\utils\data_loader.py:251: SyntaxWarning: invalid escape sequence '\P'
#   """
# c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\notebooks\..\utils\data_loader.py:290: SyntaxWarning: invalid escape sequence '\P'
#   """
# 🔌 Conectando aos bancos de dados...
# ✅ Conexões estabelecidas
#
# 📊 Carregando dados de 2025-12-01 até 2025-12-31...
#
# Discagens Expert: 1.540.513 registros
# Mailing Histórico: 1.184.839 registros
# Tabulação de Acionamentos: 7.623 registros
# Tabulação Acionamentos: 45 registros
# Calendário: 22 registros
# Pagamentos: 598 registros
# Acordos: 938 registros
# SMS: 19.408 registros
# RCS: 19.408 registros
# Email: 93.402 registros
# Telefones: 231.854 registros
# Blacklist Expert: 1.434.857 registros
# 🔌 Conexão TRC fechada
# 🔌 Conexão BD2 fechada
# 🔌 Conexão SRC fechada

# %%
import os
# #df_conflitos_score
#df_acionamentos_enriquecido_limpo, df_acion_semFaixa, df_acion_semDescricao, df_acion_semOrigem 
df_PAYJOY.to_csv('df_PAYJOY.csv', sep=';', index=False, decimal=',', encoding='utf-8-sig')
os.startfile('df_PAYJOY.csv')  # abre com o programa padrão

# %%
import importlib 
from Ouze.src import data_loader 
#from utils.data_loader import data_loader 
importlib.reload(data_loader)
# Out:
# [autoreload of utils.db_connection failed: Traceback (most recent call last):
#   File "c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\venv\Lib\site-packages\IPython\extensions\autoreload.py", line 322, in check
#     elif self.deduper_reloader.maybe_reload_module(m):
#          ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 546, in maybe_reload_module
#     new_source_code = f.read()
#   File "C:\Users\claudiano.alves\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 1466: character maps to <undefined>
# ]
# [autoreload of utils.utils failed: Traceback (most recent call last):
#   File "c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\venv\Lib\site-packages\IPython\extensions\autoreload.py", line 322, in check
#     elif self.deduper_reloader.maybe_reload_module(m):
#          ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 546, in maybe_reload_module
#     new_source_code = f.read()
#   File "C:\Users\claudiano.alves\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 2035: character maps to <undefined>
# ]
# [autoreload of utils.data_loader failed: Traceback (most recent call last):
#   File "c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\venv\Lib\site-packages\IPython\extensions\autoreload.py", line 322, in check
#     elif self.deduper_reloader.maybe_reload_module(m):
#          ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\claudiano.alves\Documents\Claudiano\repository\Data-Analysis-Portfolio\Projects\venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 546, in maybe_reload_module
#     new_source_code = f.read()
#   File "C:\Users\claudiano.alves\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 2368: character maps to <undefined>
# ]
# <module 'Ouze.src.data_loader' from 'c:\\Users\\claudiano.alves\\Documents\\Claudiano\\repository\\Data-Analysis-Portfolio\\Projects\\notebooks\\..\\Ouze\\src\\data_loader.py'>
